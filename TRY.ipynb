# %%
# Data analysis library
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
 
    
# Data visualization library
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(C:\Users\abeer\Downloads\imdb-movies-dataset.csv.zip)
df.head(2)
# Out:
#   Cell In[7], line 1
#     df=pd.read_csv(C:\Users\abeer\Downloads\imdb-movies-dataset.csv.zip)
#                     ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv("C:\Users\abeer\Downloads\imdb-movies-dataset.csv.zip")
df.head(2)
# Out:
#   Cell In[8], line 1
#     df=pd.read_csv("C:\Users\abeer\Downloads\imdb-movies-dataset.csv.zip")
#                                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df=pd.read_csv('C:\Users\abeer\Downloads\imdb-movies-dataset.csv')
df.head(2)
# Out:
#   Cell In[9], line 1
#     df=pd.read_csv('C:\Users\abeer\Downloads\imdb-movies-dataset.csv')
#                                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df=od.read_csv('C:\Users\abeer\Downloads\imdb-movies-dataset.csv')
df.head(2)
# Out:
#   Cell In[10], line 1
#     df=od.read_csv('C:\Users\abeer\Downloads\imdb-movies-dataset.csv')
#                                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df = pd.read_csv(r'C:\Users\abeer\Downloads\imdb-movies-dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\abeer\Downloads\imdb-movies-dataset.csv')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv('C:\\Users\\abeer\\Downloads\\imdb-movies-dataset.csv')
#       2 df.head(2)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv('C:\\Users\\abeer\\Downloads\\imdb-movies-dataset.csv')
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv('C:\\Users\\abeer\\Downloads\\imdb-movies-dataset.csv')
#       2 df.head(2)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
"C:\Users\abeer\imdb-movies-dataset.csv"

# %%
df = pd.read_csv('C:\\Users\\abeer\\imdb-movies-dataset.csv')
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('C:\\Users\\abeer\\imdb-movies-dataset.csv')
#       2 df.head(2)
#
# NameError: name 'pd' is not defined

# %%
df = od.read_csv('C:\\Users\\abeer\\imdb-movies-dataset.csv')
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = od.read_csv('C:\\Users\\abeer\\imdb-movies-dataset.csv')
#       2 df.head(2)
#
# NameError: name 'od' is not defined

# %%
import pandas as pd

# Now pandas (pd) is imported and defined
df = pd.read_csv('C:\\Users\\abeer\\imdb-movies-dataset.csv')
df.head(2)
# Out:
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1  https://m.media-amazon.com/images/M/MV5BZGI4NT...
#
#                                Title    Year Certificate  Duration (min)  \
# 0                    The Idea of You  2023.0           R           115.0
# 1  Kingdom of the Planet of the Apes  2023.0       PG-13           145.0
#
#                        Genre  Rating  Metascore           Director  \
# 0     Comedy, Drama, Romance     6.4       67.0  Michael Showalter
# 1  Action, Adventure, Sci-Fi     7.3       66.0           Wes Ball
#
#                                                 Cast   Votes  \
# 0  Anne Hathaway, Nicholas Galitzine, Ella Rubin,...  28,744
# 1  Owen Teague, Freya Allan, Kevin Durand, Peter ...  22,248
#
#                                          Description Review Count  \
# 0  Solène, a 40-year-old single mom, begins an un...          166
# ...

# %%
df.dtypes
# Out:
# Poster             object
# Title              object
# Year              float64
# Certificate        object
# Duration (min)    float64
# Genre              object
# Rating            float64
# Metascore         float64
# Director           object
# Cast               object
# Votes              object
# Description        object
# Review Count       object
# Review Title       object
# Review             object
# dtype: object

# %%
df.dropna(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df['Review Count']=df['Review Count'].str.replace(',','').astype(int)
df['Votes']=df['Votes'].str.replace(',','').astype(int)
df['Year']=df['Year'].astype(int)

# %%
top_rating=df[['Rating','Title']].sort_values(ascending=False ,by='Rating').head(10)


sns.barplot(data=top_rating,y='Title' ,x='Rating' )
plt.title('TOP 10 RATING MOVIES')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 top_rating=df[['Rating','Title']].sort_values(ascending=False ,by='Rating').head(10)
# ----> 4 sns.barplot(data=top_rating,y='Title' ,x='Rating' )
#       5 plt.title('TOP 10 RATING MOVIES')
#       6 plt.show()
#
# NameError: name 'sns' is not defined

# %%
top_rating=df[['Rating','Title']].sort_values(ascending=False ,by='Rating').head(10)


sns.barplot(data=top_rating,y='Title' ,x='Rating' )
plt.title('TOP 10 RATING MOVIES')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 top_rating=df[['Rating','Title']].sort_values(ascending=False ,by='Rating').head(10)
# ----> 4 sns.barplot(data=top_rating,y='Title' ,x='Rating' )
#       5 plt.title('TOP 10 RATING MOVIES')
#       6 plt.show()
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Your code continues below
top_rating = df[['Rating', 'Title']].sort_values(by='Rating', ascending=False).head(10)
sns.barplot(data=top_rating, y='Title', x='Rating')
plt.title('TOP 10 RATING MOVIES')
plt.show()

# %%
top_votes=df[['Votes','Title']].sort_values(ascending=False, by='Votes').head(10)

sns.barplot(data=top_votes  ,x='Votes' ,y='Title')
plt.title('TOP 10 HIGHEST VOTES MOVIES')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 top_votes=df[['Votes','Title']].sort_values(ascending=False, by='Votes').head(10)
#       3 sns.barplot(data=top_votes  ,x='Votes' ,y='Title')
#       4 plt.title('TOP 10 HIGHEST VOTES MOVIES')
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Your code continues below
top_rating = df[['Rating', 'Title']].sort_values(by='Rating', ascending=False).head(10)
sns.barplot(data=top_rating, y='Title', x='Rating')
plt.title('TOP 10 RATING MOVIES')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Your code continues below
# ----> 5 top_rating = df[['Rating', 'Title']].sort_values(by='Rating', ascending=False).head(10)
#       6 sns.barplot(data=top_rating, y='Title', x='Rating')
#       7 plt.title('TOP 10 RATING MOVIES')
#
# NameError: name 'df' is not defined

# %%
clear

# %%
import pandas as pd
"C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv"
# Now pandas (pd) is imported and defined
df = pd.read_csv('C:\\Users\\abeer\\Downloads\\New_folder\\imdb-movies-dataset.csv')
df.head(2)
# Out:
#   Cell In[4], line 2
#     "C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv"
#                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
"C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv"
# Now pandas (pd) is imported and defined
df = pd.read_csv('C:\\Users\\abeer\\Downloads\\New_folder\\imdb-movies-dataset.csv')
df.head(2)
# Out:
#   Cell In[5], line 2
#     "C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv"
#                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd

file_path = r"C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)
df.head(2)
# Now you can use df for further operations
# Out:
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1  https://m.media-amazon.com/images/M/MV5BZGI4NT...
#
#                                Title    Year Certificate  Duration (min)  \
# 0                    The Idea of You  2023.0           R           115.0
# 1  Kingdom of the Planet of the Apes  2023.0       PG-13           145.0
#
#                        Genre  Rating  Metascore           Director  \
# 0     Comedy, Drama, Romance     6.4       67.0  Michael Showalter
# 1  Action, Adventure, Sci-Fi     7.3       66.0           Wes Ball
#
#                                                 Cast   Votes  \
# 0  Anne Hathaway, Nicholas Galitzine, Ella Rubin,...  28,744
# 1  Owen Teague, Freya Allan, Kevin Durand, Peter ...  22,248
#
#                                          Description Review Count  \
# 0  Solène, a 40-year-old single mom, begins an un...          166
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Your code continues below
top_rating = df[['Rating', 'Title']].sort_values(by='Rating', ascending=False).head(10)
sns.barplot(data=top_rating, y='Title', x='Rating')
plt.title('TOP 10 RATING MOVIES')
plt.show()

# %%
top_votes=df[['Votes','Title']].sort_values(ascending=False, by='Votes').head(10)

sns.barplot(data=top_votes  ,x='Votes' ,y='Title')
plt.title('TOP 10 HIGHEST VOTES MOVIES')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 top_votes=df[['Votes','Title']].sort_values(ascending=False, by='Votes').head(10)
# ----> 3 sns.barplot(data=top_votes  ,x='Votes' ,y='Title')
#       4 plt.title('TOP 10 HIGHEST VOTES MOVIES')
#       5 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming top_votes is already defined correctly
# Convert 'Votes' column to numeric if necessary
top_votes['Votes'] = pd.to_numeric(top_votes['Votes'], errors='coerce')  # coerce errors to NaN if non-numeric

# Plot with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=top_votes, x='Votes', y='Title')
plt.title('TOP 10 HIGHEST VOTES MOVIES')
plt.xlabel('Votes')
plt.ylabel('Title')
plt.show()

# %%
most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
                                          by='Review Count').head(10)

sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
#       2                                           by='Review Count').head(10)
# ----> 4 sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
#       5 plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
#       6 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = {
    'Title': ['Movie A', 'Movie B', 'Movie C', 'Movie D', 'Movie E', 
              'Movie F', 'Movie G', 'Movie H', 'Movie I', 'Movie J'],
    'Review Count': ['100', '200', '150', '300', '250', 
                     '50', '75', '125', '225', '175']
}

df = pd.DataFrame(data)

# Ensure 'Review Count' is numeric
df['Review Count'] = pd.to_numeric(df['Review Count'])

# Sort the DataFrame by 'Review Count'
most_review = df[['Review Count', 'Title']].sort_values(ascending=False, by='Review Count').head(10)

# Plot
sns.barplot(data=most_review, x='Review Count', y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES')
plt.show()

# %%
most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
                                          by='Review Count').head(10)

sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming top_votes is already defined correctly
# Convert 'Votes' column to numeric if necessary
top_votes['Votes'] = pd.to_numeric(top_votes['Votes'], errors='coerce')  # coerce errors to NaN if non-numeric

# Plot with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=top_votes, x='Votes', y='Title')
plt.title('TOP 10 HIGHEST VOTES MOVIES')
plt.xlabel('Votes')
plt.ylabel('Title')
plt.show()

# %%
most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
                                          by='Review Count').head(10)

sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
                                          by='Review Count').head(10)

df = pd.DataFrame(data)

# Ensure 'Review Count' is numeric
df['Review Count'] = pd.to_numeric(df['Review Count'])

# Sort the DataFrame by 'Review Count'
most_review = df[['Review Count', 'Title']].sort_values(ascending=False, by='Review Count').head(10)

# Plot
sns.barplot(data=most_review, x='Review Count', y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES')
plt.show()

# %%
most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
                                          by='Review Count').head(10)

sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming top_votes is already defined correctly
# Convert 'Votes' column to numeric if necessary
top_votes['Votes'] = pd.to_numeric(top_votes['Votes'], errors='coerce')  # coerce errors to NaN if non-numeric

# Plot with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=top_votes, x='Votes', y='Title')
plt.title('TOP 10 HIGHEST VOTES MOVIES')
plt.xlabel('Votes')
plt.ylabel('Title')
plt.show()

# %%
most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
                                          by='Review Count').head(10)

sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
plt.show()

# %%
year_most_release_movie=df.groupby(['Year'])['Title'].count().sort_values(ascending=False).reset_index().head(10)
year_most_release_movie.rename({"Title":'Count movies'} ,axis=1 ,inplace=True)

sns.barplot(data=year_most_release_movie ,x='Year' ,y='Count movies')
plt.title('MOST RELEASED MOVIES IN YEAR')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 year_most_release_movie=df.groupby(['Year'])['Title'].count().sort_values(ascending=False).reset_index().head(10)
#       2 year_most_release_movie.rename({"Title":'Count movies'} ,axis=1 ,inplace=True)
#       4 sns.barplot(data=year_most_release_movie ,x='Year' ,y='Count movies')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example DataFrame creation (replace with your actual data loading)
data = {
    'Title': ['Movie A', 'Movie B', 'Movie C', 'Movie D', 'Movie E'],
    'Release Year': [2010, 2010, 2011, 2011, 2012]
}
df = pd.DataFrame(data)

# Group by 'Release Year' and count movies
year_most_release_movie = df.groupby(['Release Year'])['Title'].count().sort_values(ascending=False).reset_index().head(10)

# Rename the count column
year_most_release_movie.rename(columns={'Title': 'Count movies'}, inplace=True)

# Plot with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=year_most_release_movie, x='Release Year', y='Count movies')
plt.title('Top 10 Years with Most Movie Releases')
plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)  # Optional: rotate x-axis labels for better readability
plt.show()

# %%
most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
                                          by='Review Count').head(10)

sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
#       2                                           by='Review Count').head(10)
#       4 sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
#       5 plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming top_votes is already defined correctly
# Convert 'Votes' column to numeric if necessary
top_votes['Votes'] = pd.to_numeric(top_votes['Votes'], errors='coerce')  # coerce errors to NaN if non-numeric

# Plot with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=top_votes, x='Votes', y='Title')
plt.title('TOP 10 HIGHEST VOTES MOVIES')
plt.xlabel('Votes')
plt.ylabel('Title')
plt.show()

# %%
most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
                                          by='Review Count').head(10)

sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
#       2                                           by='Review Count').head(10)
#       4 sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
#       5 plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
# ...

# %%
most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
                                          by='Review Count').head(10)

sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
#       2                                           by='Review Count').head(10)
#       4 sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
#       5 plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load data from CSV file
df = pd.read_csv("C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv")  # Adjust the path as per your file location

# Step 2: Verify column names and data
print(df.head())  # Check the structure and column names

# Step 3: Sort DataFrame by 'Review Count' and select top 10
most_review = df.sort_values(by='Review Count', ascending=False).head(10)

# Step 4: Plot with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=most_review, x='Review Count', y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES')
plt.xlabel('Review Count')
plt.ylabel('Title')
plt.xticks(rotation=45)  # Optional: rotate x-axis labels for better readability
plt.show()
# Out:
#   Cell In[26], line 6
#     df = pd.read_csv("C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv")  # Adjust the path as per your file location
#                                                                                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load data from CSV file
df = df = pd.read_csv(r"C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv")  # Adjust the path as per your file location

# Step 2: Verify column names and data
print(df.head())  # Check the structure and column names

# Step 3: Sort DataFrame by 'Review Count' and select top 10
most_review = df.sort_values(by='Review Count', ascending=False).head(10)

# Step 4: Plot with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=most_review, x='Review Count', y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES')
plt.xlabel('Review Count')
plt.ylabel('Title')
plt.xticks(rotation=45)  # Optional: rotate x-axis labels for better readability
plt.show()
# Out:
#   Cell In[27], line 6
#     df = pd.read_csv("C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv")  # Adjust the path as per your file location
#                                                                                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load data from CSV file
df = df = pd.read_csv(r"C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv")  # Adjust the path as per your file location

# Step 2: Verify column names and data
print(df.head())  # Check the structure and column names

# Step 3: Sort DataFrame by 'Review Count' and select top 10
most_review = df.sort_values(by='Review Count', ascending=False).head(10)

# Step 4: Plot with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=most_review, x='Review Count', y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES')
plt.xlabel('Review Count')
plt.ylabel('Title')
plt.xticks(rotation=45)  # Optional: rotate x-axis labels for better readability
plt.show()
# Out:
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BYWRkZj...
# 1  https://m.media-amazon.com/images/M/MV5BZGI4NT...
# 2  https://m.media-amazon.com/images/M/MV5BZjIyOT...
# 3  https://m.media-amazon.com/images/M/MV5BMjA5Zj...
# 4  https://m.media-amazon.com/images/M/MV5BNTk1MT...
#
#                                Title    Year Certificate  Duration (min)  \
# 0                    The Idea of You  2023.0           R           115.0
# 1  Kingdom of the Planet of the Apes  2023.0       PG-13           145.0
# 2                          Unfrosted  2023.0       PG-13            97.0
# 3                       The Fall Guy  2023.0       PG-13           126.0
# 4                        Challengers  2023.0           R           131.0
#
#                         Genre  Rating  Metascore           Director  \
# 0      Comedy, Drama, Romance     6.4       67.0  Michael Showalter
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load data from CSV file
df = df = pd.read_csv(r"C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv")  # Adjust the path as per your file location
most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
                                          by='Review Count').head(10)

sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 10
#       6 df = df = pd.read_csv(r"C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv")  # Adjust the path as per your file location
#       7 most_review = df[['Review Count' ,'Title']].sort_values(ascending=False,
#       8                                           by='Review Count').head(10)
# ---> 10 sns.barplot(data=most_review  ,x='Review Count' ,y='Title')
#      11 plt.title('TOP 10 HIGHEST REVIEW MOVIES¶')
#      12 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data from CSV file
df = pd.read_csv(r"C:\Users\abeer\Downloads\New folder\imdb-movies-dataset.csv")

# Sort DataFrame by 'Review Count' and select top 10
most_review = df[['Review Count', 'Title']].sort_values(by='Review Count', ascending=False).head(10)

# Ensure 'Review Count' is numeric (convert if necessary)
most_review['Review Count'] = pd.to_numeric(most_review['Review Count'])

# Plot with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=most_review, x='Review Count', y='Title')
plt.title('TOP 10 HIGHEST REVIEW MOVIES')
plt.xlabel('Review Count')
plt.ylabel('Title')
plt.xticks(rotation=45)
plt.show()

# %%
year_most_release_movie=df.groupby(['Year'])['Title'].count().sort_values(ascending=False).reset_index().head(10)
year_most_release_movie.rename({"Title":'Count movies'} ,axis=1 ,inplace=True)

sns.barplot(data=year_most_release_movie ,x='Year' ,y='Count movies')
plt.title('MOST RELEASED MOVIES IN YEAR')
plt.show()

# %%
highest_meatscore=df[['Metascore','Title']].sort_values(by='Metascore' ,ascending=False).head(25)

plt.figure(figsize=(10 , 7))
bar=sns.barplot(highest_meatscore ,x='Metascore' ,y='Title')
plt.bar_label(bar.containers[0])
plt.title('Movies with Highest Metascore')
plt.show()

# %%
top_rat_year=df.groupby('Year')['Rating'].max().sort_values(ascending=False).reset_index().head(25)

plt.figure(figsize=(10 , 7))
bar=sns.barplot(top_rat_year ,y='Year' ,x='Rating' ,orient='h')
plt.bar_label(bar.containers[0])
plt.title('Movies with Highest Metascore')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px  # Import Plotly Express

# Assuming df is your DataFrame loaded from the CSV file

# Create a pivot table
genre = df.pivot_table(index='Genre', columns='Year', values='Rating').fillna(0).astype(int)

# Plot with Plotly Express
plt.figure(figsize=(10, 10))
px.imshow(genre)

plt.title('Genre vs Year vs Rating')
plt.xlabel('Year')
plt.ylabel('Genre')
plt.show()
